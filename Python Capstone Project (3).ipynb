# %%
import pandas as pd

# %% [markdown]
# #  Task1 :Load the movie dataset and display the first 50 movies

# %%
df=pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df.shape
# Out:
# (4803, 20)

# %% [markdown]
# # Top 50 movies with categories name

# %%
top_50_movie=df.head(50)
top_50_movie
list_of_top=top_50_movie[['original_title','genres']]
list_of_top
# Out:
#                                  original_title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# # Identifying and handling null values

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
df.dtypes
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# dtype: object

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64'])
categorical_columns = df.select_dtypes(include=['object'])

from tabulate import tabulate
table = [numerical_columns, categorical_columns]
print(tabulate({"Numerical":numerical_columns,
                "Categorical": categorical_columns}, headers = ["numerical_columns", "categorical_columns"]))
# Out:
# numerical_columns    categorical_columns
# -------------------  ---------------------
# budget               genres
# id                   homepage
# popularity           keywords
# revenue              original_language
# runtime              original_title
# vote_average         overview
# vote_count           production_companies
#                      production_countries
#                      release_date
#                      spoken_languages
#                      status
#                      tagline
#                      title

# %% [markdown]
# # Separating Categorical and Numerical columns

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# Fill missing values in numerical columns with the median
for column in numerical_columns:
    mean = df[column].mean()  
    df[column].fillna(mean, inplace=True)

# %%
for column in categorical_columns:
    mode_value = df[column].mode().iloc[0]  
    df[column].fillna(mode_value, inplace=True)

# %%
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# # Top 50 movies with categories name

# %%
import ast

# %%
df['genres'] = df['genres'].apply(ast.literal_eval)

df['categories'] = df['genres'].apply(lambda x: ', '.join([genre['name'] for genre in x]))

# %%
top_50_movie=df.head(50)
top_50_movie
list_of_top=top_50_movie[['original_title','categories']]
list_of_top
# Out:
#                                  original_title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# # Displaying the categories that have a budget greater than 220,000

# %%
budget_gt_220k = df[df['budget'] > 220000]
print("Movie categories with budget > $220,000:")
print(budget_gt_220k['categories'])
# Out:
# Movie categories with budget > $220,000:
# 0       Action, Adventure, Fantasy, Science Fiction
# 1                        Adventure, Fantasy, Action
# 2                          Action, Adventure, Crime
# 3                    Action, Crime, Drama, Thriller
# 4                Action, Adventure, Science Fiction
#                            ...
# 4680                        Crime, Horror, Thriller
# 4682                                         Horror
# 4720                                          Drama
# 4758                      Thriller, Science Fiction
# 4770                                  Drama, Comedy
# Name: categories, Length: 3684, dtype: object

# %% [markdown]
# # Displaing movie categories with revenue > 961,000,000

# %%
print("Movie categories with revenue > $961,000,000:")
revenue_gt_961 = df[df['revenue'] > 961000000]
print(revenue_gt_961['categories'])
# Out:
# Movie categories with revenue > $961,000,000:
# 0       Action, Adventure, Fantasy, Science Fiction
# 3                    Action, Crime, Drama, Thriller
# 7                Action, Adventure, Science Fiction
# 12                       Adventure, Fantasy, Action
# 16               Science Fiction, Action, Adventure
# 17                       Adventure, Action, Fantasy
# 25                         Drama, Romance, Thriller
# 26               Adventure, Action, Science Fiction
# 28     Action, Adventure, Science Fiction, Thriller
# 29                      Action, Adventure, Thriller
# 31               Action, Adventure, Science Fiction
# 32                       Family, Fantasy, Adventure
# 36               Science Fiction, Action, Adventure
# 42                        Animation, Family, Comedy
# 44                                           Action
# 52               Action, Science Fiction, Adventure
# 65                   Drama, Action, Crime, Thriller
# ...

# %% [markdown]
# # Removing rows with budget and revenue column having value=0

# %%
df = df[(df['budget'] > 0) & (df['revenue'] > 0)]

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1     300000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2     245000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3     250000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4     260000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# ...         ...                                                ...
# 4773      27000                     [{'id': 35, 'name': 'Comedy'}]
# 4788      12000  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 4792      20000  [{'id': 80, 'name': 'Crime'}, {'id': 27, 'name...
# 4796       7000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 4798     220000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # List  of top 10 movies with highest revenue and least budget

# %%
top_revenue = df.nlargest(10, 'revenue')
top_budget = df.nsmallest(10, 'budget')
print("Top 10 movies with the highest revenue:")
print(top_revenue[['original_title','revenue']])
print("Top 10 movies with the least budget:")
print(top_budget[['original_title','budget']])
# Out:
# Top 10 movies with the highest revenue:
#                  original_title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495
# Top 10 movies with the least budget:
#           original_title  budget
# 4238        Modern Times       1
# 3611  A Farewell to Arms       4
# 3372        Split Second       7
# 3419        Bran Nue Dae       7
# 4608        The Prophecy       8
# 3131         Hross í oss      10
# 3137           Nurse 3-D      10
# 2933            F.I.S.T.      11
# 1912      Angela's Ashes      25
# 1771      The 51st State      28

# %% [markdown]
# # Analyzing the correlation between popularity and budget

# %%
correlation = df['popularity'].corr(df['budget'])
print("Correlation between popularity and budget:", correlation)
# Out:
# Correlation between popularity and budget: 0.4319901360079756

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['budget'],df['popularity'],color='m')
plt.xlabel('Budget')
plt.ylabel('Popularity')
plt.title("Correlation between Popularity and Budget")
plt.show()

# %% [markdown]
# # Identifying and displaying production companies along with their counts

# %%
import json
# Convert the string representation of production companies into a list of dictionaries
df['production_companies'] = df['production_companies'].apply(lambda x: json.loads(x))
# Out:
# C:\Users\GHANAS~1\AppData\Local\Temp/ipykernel_10824/2207180011.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['production_companies'] = df['production_companies'].apply(lambda x: json.loads(x))

# %%
# # Initialize an empty dictionary to store production company names and their counts
production_counts = {}

# Iterate over each row in the DataFrame
for row in df.itertuples(index=False):
    # Iterate over each production company in the row
    for company in row.production_companies:
        # Extract the production company name
        company_name = company['name']
        
        # Increment the count for the production company
        if company_name in production_counts:
            production_counts[company_name] += 1
        else:
            production_counts[company_name] = 1

# Create a new DataFrame to store the production company names and their counts
production_df = pd.DataFrame({'Production Company': list(production_counts.keys()), 'Count': list(production_counts.values())})

# Sort the DataFrame by count in descending order
production_df = production_df.sort_values('Count', ascending=False)
print("Production companies by the number of movies produced:")
production_df
# Out:
# Production companies by the number of movies produced:
#                           Production Company  Count
# 11                              Warner Bros.    280
# 52                        Universal Pictures    273
# 38                        Paramount Pictures    245
# 1     Twentieth Century Fox Film Corporation    201
# 7                          Columbia Pictures    167
# ...                                      ...    ...
# 1685                                  HW Two      1
# 1687                        Unfinished Films      1
# 1688         Infinity Features Entertainment      1
# 1690                   British Columbia Film      1
# 3563                           Daiei Studios      1
#
# [3564 rows x 2 columns]

# %% [markdown]
# # Displaying the names of the top 25 production companies by the number of movies produced

# %%
# Display the top 25 production companies
top_producers = production_df.head(25)
print("Top 25 production companies by the number of movies produced:")
top_producers
# Out:
# Top 25 production companies by the number of movies produced:
#                           Production Company  Count
# 11                              Warner Bros.    280
# 52                        Universal Pictures    273
# 38                        Paramount Pictures    245
# 1     Twentieth Century Fox Film Corporation    201
# 7                          Columbia Pictures    167
# 46                           New Line Cinema    142
# 54                          Relativity Media    100
# 4                       Walt Disney Pictures     96
# 193                      Touchstone Pictures     93
# 49                 Metro-Goldwyn-Mayer (MGM)     92
# 250            Columbia Pictures Corporation     86
# 112                Village Roadshow Pictures     73
# 384                            Miramax Films     67
# 80                            DreamWorks SKG     67
# 522                           United Artists     64
# 289                      Regency Enterprises     59
# ...

# %% [markdown]
# # Sorting data by revenue, filtering top 500 movies, and calculating central tendency measures

# %%
top_500_revenue = df.sort_values(by='revenue', ascending=False).head(500)
print("Central tendency measures for budget:")
print(top_500_revenue['budget'].describe())
print("Central tendency measures for revenue:")
print(top_500_revenue['revenue'].describe())
print("Central tendency measures for runtime:")
print(top_500_revenue['runtime'].describe())
# Out:
# Central tendency measures for budget:
# count    5.000000e+02
# mean     1.031937e+08
# std      6.224893e+07
# min      6.000000e+04
# 25%      5.500000e+07
# 50%      9.500000e+07
# 75%      1.500000e+08
# max      3.800000e+08
# Name: budget, dtype: float64
# Central tendency measures for revenue:
# count    5.000000e+02
# mean     4.585776e+08
# std      2.685357e+08
# min      2.177643e+08
# 25%      2.814473e+08
# 50%      3.630016e+08
# 75%      5.471332e+08
# max      2.787965e+09
# Name: revenue, dtype: float64
# Central tendency measures for runtime:
# count    500.000000
# mean     118.720000
# std       23.257158
# min       70.000000
# 25%      100.000000
# 50%      116.000000
# 75%      132.000000
# max      238.000000
# Name: runtime, dtype: float64

# %% [markdown]
# # Outlier analysis using box plots

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.boxplot(top_500_revenue['budget'])
plt.title("Budget Box Plot")

plt.subplot(132)
plt.boxplot(top_500_revenue['revenue'])
plt.title("Revenue Box Plot")

plt.subplot(133)
plt.boxplot(top_500_revenue['runtime'])
plt.title("Runtime Box Plot")
# Out:
# Text(0.5, 1.0, 'Runtime Box Plot')

# %% [markdown]
# **Interpretations:In the box we can able to see the revenue column has maximum number of outliers and in budget 2 outliers are present.

# %% [markdown]
# # Displaying movies with above-average runtime from the top 500 movies

# %%
average_runtime = top_500_revenue['runtime'].mean()
above_average_runtime = top_500_revenue[top_500_revenue['runtime'] > average_runtime]
print("Movies with above-average runtime:")
print(above_average_runtime[['original_title', 'runtime']])
# Out:
# Movies with above-average runtime:
#         original_title  runtime
# 0               Avatar    162.0
# 25             Titanic    194.0
# 16        The Avengers    143.0
# 28      Jurassic World    124.0
# 44           Furious 7    137.0
# ...                ...      ...
# 521       The Terminal    128.0
# 397   It's Complicated    121.0
# 1744        Knocked Up    129.0
# 717       Jack Reacher    130.0
# 714         Collateral    120.0
#
# [234 rows x 2 columns]

# %%
import warnings
warnings.filterwarnings('ignore')
